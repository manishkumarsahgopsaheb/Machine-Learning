# %%
import pandas as pd

# %%
df = pd.read_csv("G:\\datasets\\student_results.csv")
df
# Out:
#    Student ID  Class  Study hrs  Sleeping hrs  Social Media usage hrs  \
# 0        1001     10          2             9                       3
# 1        1002     10          6             8                       2
# 2        1003     10          3             8                       2
# 3        1004     11          0            10                       1
# 4        1005     11          4             7                       2
# 5        1006     11         10             7                       0
# 6        1007     12          4             6                       0
# 7        1008     12         10             6                       2
# 8        1009     12          2             8                       2
# 9        1010     12          6             9                       1
#
#    Mobile Games hrs  Percantege
# 0                 5          50
# 1                 0          80
# 2                 4          60
# 3                 5          45
# ...

# %%
# now i want to make 3rd row as header
df = pd.read_csv("G:\\datasets\\student_results.csv", header = 3)
df
# Out:
#    1003  10   3   8  2  4  60
# 0  1004  11   0  10  1  5  45
# 1  1005  11   4   7  2  0  75
# 2  1006  11  10   7  0  0  96
# 3  1007  12   4   6  0  0  80
# 4  1008  12  10   6  2  0  90
# 5  1009  12   2   8  2  4  60
# 6  1010  12   6   9  1  0  85

# %%
pd.read_csv("G:\\datasets\\student_results.csv", header = None) # header none will give the default indexing to the column starting from 0
# Out:
#              0      1          2             3                       4  \
# 0   Student ID  Class  Study hrs  Sleeping hrs  Social Media usage hrs
# 1         1001     10          2             9                       3
# 2         1002     10          6             8                       2
# 3         1003     10          3             8                       2
# 4         1004     11          0            10                       1
# 5         1005     11          4             7                       2
# 6         1006     11         10             7                       0
# 7         1007     12          4             6                       0
# 8         1008     12         10             6                       2
# 9         1009     12          2             8                       2
# 10        1010     12          6             9                       1
#
#                    5           6
# 0   Mobile Games hrs  Percantege
# 1                  5          50
# ...

# %%
# use of prefix
pd.read_csv("G:\\datasets\\student_results.csv", header = None, prefix = 'data') # while using prefix, you have to make sure that you rae using header = None
# Out:
#          data0  data1      data2         data3                   data4  \
# 0   Student ID  Class  Study hrs  Sleeping hrs  Social Media usage hrs
# 1         1001     10          2             9                       3
# 2         1002     10          6             8                       2
# 3         1003     10          3             8                       2
# 4         1004     11          0            10                       1
# 5         1005     11          4             7                       2
# 6         1006     11         10             7                       0
# 7         1007     12          4             6                       0
# 8         1008     12         10             6                       2
# 9         1009     12          2             8                       2
# 10        1010     12          6             9                       1
#
#                data5       data6
# 0   Mobile Games hrs  Percantege
# 1                  5          50
# ...

# %%
pd.read_csv("G:\\datasets\\student_results.csv", header = None, prefix = 'manish ')
# Out:
#       manish 0 manish 1   manish 2      manish 3                manish 4  \
# 0   Student ID    Class  Study hrs  Sleeping hrs  Social Media usage hrs
# 1         1001       10          2             9                       3
# 2         1002       10          6             8                       2
# 3         1003       10          3             8                       2
# 4         1004       11          0            10                       1
# 5         1005       11          4             7                       2
# 6         1006       11         10             7                       0
# 7         1007       12          4             6                       0
# 8         1008       12         10             6                       2
# 9         1009       12          2             8                       2
# 10        1010       12          6             9                       1
#
#             manish 5    manish 6
# 0   Mobile Games hrs  Percantege
# ...

# %%
# use of names parameter
pd.read_csv("G:\\datasets\\student_results.csv", names = ['A', 'B', 'C', 'D', 'E', 'F', 'G'])
# Out:
#              A      B          C             D                       E  \
# 0   Student ID  Class  Study hrs  Sleeping hrs  Social Media usage hrs
# 1         1001     10          2             9                       3
# 2         1002     10          6             8                       2
# 3         1003     10          3             8                       2
# 4         1004     11          0            10                       1
# 5         1005     11          4             7                       2
# 6         1006     11         10             7                       0
# 7         1007     12          4             6                       0
# 8         1008     12         10             6                       2
# 9         1009     12          2             8                       2
# 10        1010     12          6             9                       1
#
#                    F           G
# 0   Mobile Games hrs  Percantege
# 1                  5          50
# ...

# %%
# use of head() and tail() of pandas module
df = pd.read_csv("G:\\datasets\\student_results.csv")
df
# Out:
#    Student ID  Class  Study hrs  Sleeping hrs  Social Media usage hrs  \
# 0        1001     10          2             9                       3
# 1        1002     10          6             8                       2
# 2        1003     10          3             8                       2
# 3        1004     11          0            10                       1
# 4        1005     11          4             7                       2
# 5        1006     11         10             7                       0
# 6        1007     12          4             6                       0
# 7        1008     12         10             6                       2
# 8        1009     12          2             8                       2
# 9        1010     12          6             9                       1
#
#    Mobile Games hrs  Percantege
# 0                 5          50
# 1                 0          80
# 2                 4          60
# 3                 5          45
# ...

# %%
df.head() # by default head() will print the first five or from top five data row
# Out:
#    Student ID  Class  Study hrs  Sleeping hrs  Social Media usage hrs  \
# 0        1001     10          2             9                       3
# 1        1002     10          6             8                       2
# 2        1003     10          3             8                       2
# 3        1004     11          0            10                       1
# 4        1005     11          4             7                       2
#
#    Mobile Games hrs  Percantege
# 0                 5          50
# 1                 0          80
# 2                 4          60
# 3                 5          45
# 4                 0          75

# %%
df.tail() # same by default tail() will also print the last five or buttom five data row
# Out:
#    Student ID  Class  Study hrs  Sleeping hrs  Social Media usage hrs  \
# 5        1006     11         10             7                       0
# 6        1007     12          4             6                       0
# 7        1008     12         10             6                       2
# 8        1009     12          2             8                       2
# 9        1010     12          6             9                       1
#
#    Mobile Games hrs  Percantege
# 5                 0          96
# 6                 0          80
# 7                 0          90
# 8                 4          60
# 9                 0          85

# %%
df.head(2)
# Out:
#    Student ID  Class  Study hrs  Sleeping hrs  Social Media usage hrs  \
# 0        1001     10          2             9                       3
# 1        1002     10          6             8                       2
#
#    Mobile Games hrs  Percantege
# 0                 5          50
# 1                 0          80

# %%
df.tail(3)
# Out:
#    Student ID  Class  Study hrs  Sleeping hrs  Social Media usage hrs  \
# 7        1008     12         10             6                       2
# 8        1009     12          2             8                       2
# 9        1010     12          6             9                       1
#
#    Mobile Games hrs  Percantege
# 7                 0          90
# 8                 4          60
# 9                 0          85

# %%
# changing dtype of column
df = pd.read_csv("G:\\datasets\\student_results.csv", dtype = {'Student ID':'float64'}) # dtype is taking the dictionary. so for multiple column you can change the data type of the column
df
# Out:
#    Student ID  Class  Study hrs  Sleeping hrs  Social Media usage hrs  \
# 0      1001.0     10          2             9                       3
# 1      1002.0     10          6             8                       2
# 2      1003.0     10          3             8                       2
# 3      1004.0     11          0            10                       1
# 4      1005.0     11          4             7                       2
# 5      1006.0     11         10             7                       0
# 6      1007.0     12          4             6                       0
# 7      1008.0     12         10             6                       2
# 8      1009.0     12          2             8                       2
# 9      1010.0     12          6             9                       1
#
#    Mobile Games hrs  Percantege
# 0                 5          50
# 1                 0          80
# 2                 4          60
# 3                 5          45
# ...

# %%
df = pd.read_csv("G:\\datasets\\student_results.csv", dtype = {'Student ID':'float64', 'Class':'float64'})
df
# Out:
#    Student ID  Class  Study hrs  Sleeping hrs  Social Media usage hrs  \
# 0      1001.0   10.0          2             9                       3
# 1      1002.0   10.0          6             8                       2
# 2      1003.0   10.0          3             8                       2
# 3      1004.0   11.0          0            10                       1
# 4      1005.0   11.0          4             7                       2
# 5      1006.0   11.0         10             7                       0
# 6      1007.0   12.0          4             6                       0
# 7      1008.0   12.0         10             6                       2
# 8      1009.0   12.0          2             8                       2
# 9      1010.0   12.0          6             9                       1
#
#    Mobile Games hrs  Percantege
# 0                 5          50
# 1                 0          80
# 2                 4          60
# 3                 5          45
# ...

# %%
# let me make some change in my dataset
df = pd.read_csv("G:\\datasets\\student_results.csv")

# %%
df
# Out:
#    Student ID Date  Class  Study hrs  Sleeping hrs  Social Media usage hrs  \
# 0        1001  yes     10          2             9                       3
# 1        1002  yes     10          6             8                       2
# 2        1003  yes     10          3             8                       2
# 3        1004  yes     11          0            10                       1
# 4        1005  yes     11          4             7                       2
# 5        1006  yes     11         10             7                       0
# 6        1007  yes     12          4             6                       0
# 7        1008  yes     12         10             6                       2
# 8        1009  yes     12          2             8                       2
# 9        1010  yes     12          6             9                       1
#
#    Mobile Games hrs  Percantege
# 0                 5          50
# 1                 0          80
# 2                 4          60
# ...

# %%
# changing yes as true using true_values parameter
df = pd.read_csv("G:\\datasets\\student_results.csv", true_values = ['yes'], false_values = ['no'])
df
# Out:
#    Student ID   Date  Class  Study hrs  Sleeping hrs  Social Media usage hrs  \
# 0        1001   True     10          2             9                       3
# 1        1002  False     10          6             8                       2
# 2        1003   True     10          3             8                       2
# 3        1004   True     11          0            10                       1
# 4        1005   True     11          4             7                       2
# 5        1006  False     11         10             7                       0
# 6        1007   True     12          4             6                       0
# 7        1008   True     12         10             6                       2
# 8        1009  False     12          2             8                       2
# 9        1010   True     12          6             9                       1
#
#    Mobile Games hrs  Percantege
# 0                 5          50
# 1                 0          80
# ...

# %%
# in same way for unnecessary string we can change that in false, using false_values
# making change in the dataset
df = pd.read_csv("G:\\datasets\\student_results.csv")
df
# Out:
#    Student ID Date  Class  Study hrs  Sleeping hrs  Social Media usage hrs  \
# 0        1001  yes     10          2             9                       3
# 1        1002   no     10          6             8                       2
# 2        1003  yes     10          3             8                       2
# 3        1004  yes     11          0            10                       1
# 4        1005  yes     11          4             7                       2
# 5        1006   no     11         10             7                       0
# 6        1007  yes     12          4             6                       0
# 7        1008  yes     12         10             6                       2
# 8        1009   no     12          2             8                       2
# 9        1010  yes     12          6             9                       1
#
#    Mobile Games hrs  Percantege
# 0                 5          50
# 1                 0          80
# 2                 4          60
# ...

# %%
df = pd.read_csv("G:\\datasets\\student_results.csv", true_values = ['yes'], false_values = ['no'])
df
# Out:
#    Student ID   Date  Class  Study hrs  Sleeping hrs  Social Media usage hrs  \
# 0        1001   True     10          2             9                       3
# 1        1002  False     10          6             8                       2
# 2        1003   True     10          3             8                       2
# 3        1004   True     11          0            10                       1
# 4        1005   True     11          4             7                       2
# 5        1006  False     11         10             7                       0
# 6        1007   True     12          4             6                       0
# 7        1008   True     12         10             6                       2
# 8        1009  False     12          2             8                       2
# 9        1010   True     12          6             9                       1
#
#    Mobile Games hrs  Percantege
# 0                 5          50
# 1                 0          80
# ...
